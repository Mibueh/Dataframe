# %%
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
class Nba:
    def excel(self):
        global nba
        global group
        excel_file = 'NBA.xlsx'
        nba = pd.read_excel(excel_file, index_col='Nombre')
        group = nba.sort_values(['Posicion'], ascending=False)
        group.head(50)
        
    def posicion(self):
        global clave
        fig=plt.figure(figsize=(30,10))
        plt.subplot2grid((2,4),(0,0))
        clave = nba['Posicion']
        clave.value_counts().plot(kind='bar', alpha=0.5)
        plt.title('Posiciones más jugadas')
        plt.show()
        
    def pivot(self):
        fig=plt.figure(figsize=(30,10))
        plt.subplot2grid((2,4),(0,0))
        pivot = nba.groupby(['Posicion']).get_group(('Pivot'))
        rebote = pivot.sort_values(['Rebotes'], ascending=False)
        rebote.head(10).plot(kind="bar", alpha=0.5)
        plt.title('Pivot')
        plt.show()
        
    def base(self):
        pivot = nba.groupby(['Posicion']).get_group(('Base'))
        asistencia = pivot.sort_values(['Asistencia'], ascending=False)
        asistencia.plot(kind="bar")
        plt.title('Base')
        plt.figure(figsize=(20,10))
        plt.show()
        
    def alero(self):
        alero = nba.groupby(['Posicion']).get_group(('Alero'))
        triple = pivot.sort_values(['Triples'], ascending=False)
        triple.head(10).plot(kind="bar")
        plt.title('Alero')
        plt.show()
        
    def escolta(self):
        escolta = nba.groupby(['Posicion']).get_group(('Pivot'))
        puntos = escolta.sort_values(['Puntos'], ascending=False)
        puntos.head(10).plot(kind="bar")
        plt.title('Escolta')
        plt.show()

# %%
grafica = Nba()
grafica.alero()

# %%
hola = Nba()
hola.excel()

# %%
group.head(20)
# Out:
#                           Equipo  Edad  Salario Posicion  Rebotes  Robos  \
# Nombre
# Joel Embiid                76ers   NaN      NaN    Pivot     11.9    0.2
# Nikola Jokic             Nuggets   NaN      NaN    Pivot     10.0    1.3
# Anthony David           Pelicans   NaN      NaN    Pivot     13.0    2.0
# Karl-Anthony Towns  Timberwolves   NaN      NaN    Pivot     10.6    0.9
# Jimmy Butler        Timberwolves   NaN      NaN  Escolta      5.0    2.6
# Victor Oladipo            Pacers   NaN      NaN  Escolta      5.9    1.6
# James Harden             Rockets   NaN      NaN  Escolta      6.3    2.0
# Damian Lillard           Blazers   NaN      NaN     Base      5.1    0.6
# Klay Thompson           Warriors   NaN      NaN     Base      4.1    0.7
# Kyrie Irving             Celtics   NaN      NaN     Base      4.6    0.9
# Stephen Curry           Warriors   NaN      NaN     Base      5.0    1.1
# Russel Westbrook    City Thunder   NaN      NaN     Base      9.6    2.3
# Chris Paul               Rockets   NaN      NaN     Base      5.8    1.8
# Lebron James              Lakers   NaN      NaN    Alero      8.6    2.1
# Ben Simmons                76ers   NaN      NaN    Alero      9.5    1.0
# Draymond Green          Warriors   NaN      NaN    Alero      7.3    2.0
# Kevin Durant            Warriors   NaN      NaN    Alero      7.1    1.3
# Paul George         City Thunder   NaN      NaN    Alero      7.1    2.4
# Kawhi Leonard             Raptor   NaN      NaN    Alero      7.8    2.0
#
#                     Triples  Asistencia  Puntos  Edad.1  Puntuacion
# Nombre
# Joel Embiid             1.4         3.8    28.6      24        44.3
# Nikola Jokic            1.4         6.6    19.4      23        36.0
# Anthony David           1.0         5.2    25.2      25        43.4
# Karl-Anthony Towns      2.2         2.4    18.9      22        31.9
# Jimmy Butler            1.7         3.6    22.3      29        26.6
# Victor Oladipo          2.2         4.4    22.0      26        25.8
# James Harden            3.8         9.0    28.5      29        34.3
# Damian Lillard          3.0         6.0    29.1      28        35.7
# Klay Thompson           2.4         1.4    19.6      28        21.7
# Kyrie Irving            2.1         5.6    17.9      26        24.4
# Stephen Curry           5.9         5.9    33.0      30        40.0
# Russel Westbrook        0.3         8.2    25.8      29        36.3
# Chris Paul              2.6         8.3    19.0      33        29.1
# Lebron James            1.5         8.0    27.8      33        37.9
# Ben Simmons             0.0         8.4    13.8      22        23.3
# Draymond Green          0.6         8.2     8.3      28        16.2
# Kevin Durant            1.7         6.2    27.8      30        36.6
# Paul George             2.9         3.4    23.4      28        33.4
# Kawhi Leonard           1.9         3.2    27.3      27        37.0

# %%
fig=plt.figure(figsize=(30,10))
plt.subplot2grid((2,4),(0,0))
clave = nba['Posicion']
clave.value_counts().plot(kind='bar', alpha=0.5)
plt.title('Posiciones más jugadas')
plt.show()
